# %%
from phone import Phone
def getlocation(num):
    if ';' in num:
        nums=num.split(';')
        for i in nums:
            if len(str(i))==11:
                try:
                    info=Phone().find(i)
                    city = info['city']
                    return city 
                except Exception as e:
#                     print(e)
                    return ""
    else:
         if len(str(num))==11:
                try:
                    info=Phone().find(num)
                    city = info['city']
                    return city 
                except Exception as e:
#                     print(e)
                    return ""

# %%
import pandas as pd
new_df=pd.read_csv('gcj融合4poi.csv',engine='python',encoding='utf_8_sig')

# %%
new_df['area'] = new_df.apply(lambda x: getlocation(x['TELEPHONE']), axis=1)
new_df.head()
# Out:
#         NAME   ADDRESS TELEPHONE PROVINCE CITY COUNTY    CODE  TYPECODE  \
# 0        停车场    立业路6附近                湖北省  武汉市    蔡甸区  420114  150904.0
# 1        停车场   软件园路6附近                湖北省  武汉市    洪山区  420111  150904.0
# 2  停车场(沿江大道)  沿江大道131号                湖北省  武汉市    江岸区  420102  150904.0
# 3        停车场   芦沟桥路4附近                湖北省  武汉市    江岸区  420102  150904.0
# 4    滨湖大厦停车场  黄鹂路46号附近                湖北省  武汉市    武昌区  420106  150904.0
#
#   BASETYPE SUBTYPE CATEGORY      wgslng     wgslat  area
# 0   交通设施服务     停车场    公共停车场  114.154421  30.492735  None
# 1   交通设施服务     停车场    公共停车场  114.401281  30.476192  None
# 2   交通设施服务     停车场    公共停车场  114.292220  30.579073  None
# 3   交通设施服务     停车场    公共停车场  114.306617  30.609085  None
# 4   交通设施服务     停车场    公共停车场  114.356906  30.564972  None

# %%
import numpy as np
new_df['area'].fillna(value="", inplace=True)

# %%
new_df.head()
# Out:
#         NAME   ADDRESS TELEPHONE PROVINCE CITY COUNTY    CODE  TYPECODE  \
# 0        停车场    立业路6附近                湖北省  武汉市    蔡甸区  420114  150904.0
# 1        停车场   软件园路6附近                湖北省  武汉市    洪山区  420111  150904.0
# 2  停车场(沿江大道)  沿江大道131号                湖北省  武汉市    江岸区  420102  150904.0
# 3        停车场   芦沟桥路4附近                湖北省  武汉市    江岸区  420102  150904.0
# 4    滨湖大厦停车场  黄鹂路46号附近                湖北省  武汉市    武昌区  420106  150904.0
#
#   BASETYPE SUBTYPE CATEGORY      wgslng     wgslat area
# 0   交通设施服务     停车场    公共停车场  114.154421  30.492735
# 1   交通设施服务     停车场    公共停车场  114.401281  30.476192
# 2   交通设施服务     停车场    公共停车场  114.292220  30.579073
# 3   交通设施服务     停车场    公共停车场  114.306617  30.609085
# 4   交通设施服务     停车场    公共停车场  114.356906  30.564972

# %%
wh_df=new_df[new_df['area']!=""]

# %%
wh_df[wh_df['area']!="武汉"]
# Out:
#                       NAME                                 ADDRESS  \
# 7664            有间住宿(藏龙北街)                             学府四季商业街160号
# 7728            银华宾馆(钟家村店)                                 西大街134号
# 7962                  宏祥宾馆                                 博学路148号
# 7981                  广来旅社                                 贸易二路28号
# 8039               武汉成功出租屋                             宝丰街宝康路宝丰巷4号
# 8051              武汉1705公寓                        硚口路135号航天星苑1705号
# 8155          宝丽金单身公寓日租短租房                                江汉路商圈花楼街
# 8159         武汉百花园宾馆(江汉路店)                                前进二路111号
# 8165                  南湖公寓                                 恒安路359号
# 8172                  金凯旅店                                  自由路43号
# 8190             天骄宾馆(胭脂路)                             粮道街243号附11号
# 8235                武汉洪天公寓                          宏昌路团结名居桔园1单元6层
# 8238        武汉时尚旅馆(徐东村小区店)                          徐东一路徐东村小区6栋1单元
# ...

# %%
import pandas as pd
df=pd.read_csv('NetChina.csv',encoding='utf_8_sig',engine='python',sep=',')
# tmpdf2017=pd.read_csv("NetChina.csv") 
# with open('djschina.txt','r',encoding='utf-8') as f:
#    tmp= f.readlines()

# %%
df.head()
# Out:
#         City  Province                                           url  ID
# 0  阿坝藏族羌族自治州       四川省    http://www.hotelaah.com/sichuan/index.html   1
# 1      阿克苏地区  新疆维吾尔自治区   http://www.hotelaah.com/xinjiang/index.html   2
# 2       阿拉善盟    内蒙古自治区  http://www.hotelaah.com/neimenggu/index.html   3
# 3      阿勒泰地区  新疆维吾尔自治区   http://www.hotelaah.com/xinjiang/index.html   4
# 4       阿里地区     西藏自治区     http://www.hotelaah.com/xizang/index.html   5
