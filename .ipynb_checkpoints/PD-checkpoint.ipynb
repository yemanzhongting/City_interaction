# %%
import pandas as pd
new_df=pd.read_csv('gcj融合4poi.csv',engine='python',encoding='utf_8_sig')

# %%
bashtypes=set(new_df['BASETYPE'].values.tolist())
bashtypes

# %%
panduan={}
for i in bashtypes:
    panduan[i]=set(new_df[new_df['BASETYPE']==i]['CATEGORY'].values.tolist())

# %%
BertRe=pd.read_csv('bertword70105.csv',engine='python',sep=',',encoding='utf_8_sig')
BertRe.head()
# Out:
#                                             CATEGORY  IDS  NUMS  \
# 0  政府及社会团体相关 政府机关相关 生活服务场所 乡镇以下级政府及事业单位 乡镇以下级政府及事...    0    11
# 1                                     物流速递 政府及社会团体相关    1     2
# 2  其它农林牧渔基地 物流速递 汽车维修 公司 餐饮相关 餐饮相关 中餐厅 快餐厅 公交车站相关...    2    27
# 3                              路口名 餐饮相关 公证鉴定机构 公司 小学    3     5
# 4                                               餐饮相关    4     1
#
#                                              SUBTYPE  Topic  Doc_ID
# 0  政府及社会团体相关 政府机关 生活服务场所 政府机关 政府机关 政府机关 临街院门 物流速递...      5       0
# 1                                     物流速递 政府及社会团体相关     -1       1
# 2  农林牧渔基地 物流速递 汽车维修 公司 餐饮相关场所 餐饮相关场所 中餐厅 快餐厅 公交车站...     -1       2
# 3                            交通地名 餐饮相关场所 公检法机构 公司 学校     -1       3
# 4                                             餐饮相关场所      6       4

# %%
BertRe['Topic'].value_counts()
# Out:
# -1    848
#  4    242
#  5    217
#  2    162
#  0    158
#  1    123
#  3    114
#  6    112
# Name: Topic, dtype: int64

# %%
BertRe['BertIds']=BertRe.index

# %%
GridJoin=pd.read_csv('GridJoin.csv',engine='python',sep=',',encoding='utf_8_sig')
GridJoin.head()
# Out:
#                                             CATEGORY  IDS  NUMS  \
# 0  政府及社会团体相关 政府机关相关 生活服务场所 乡镇以下级政府及事业单位 乡镇以下级政府及事...    0    11
# 1                                     物流速递 政府及社会团体相关    1     2
# 2  其它农林牧渔基地 物流速递 汽车维修 公司 餐饮相关 餐饮相关 中餐厅 快餐厅 公交车站相关...    2    27
# 3                              路口名 餐饮相关 公证鉴定机构 公司 小学    3     5
# 4                                               餐饮相关    4     1
#
#                                              SUBTYPE  OBJECTID  Label  \
# 0  政府及社会团体相关 政府机关 生活服务场所 政府机关 政府机关 政府机关 临街院门 物流速递...         1     28
# 1                                     物流速递 政府及社会团体相关         2     29
# 2  农林牧渔基地 物流速递 汽车维修 公司 餐饮相关场所 餐饮相关场所 中餐厅 快餐厅 公交车站...         3     30
# 3                            交通地名 餐饮相关场所 公检法机构 公司 学校         4     31
# 4                                             餐饮相关场所         5     32
#
#           lng        lat
# 0  114.291718  30.462484
# 1  114.296722  30.462484
# 2  114.301720  30.462484
# 3  114.306725  30.462484
# 4  114.311722  30.462484

# %%
BertRe[['Topic','Doc_ID','BertIds']]

# %%
BertGridJoin=pd.merge(GridJoin,BertRe[['Topic','Doc_ID','BertIds']],how='left',left_on = 'IDS' ,right_on = 'BertIds')#.drop('ID',axis=1)
BertGridJoin.head()
# Out:
#                                             CATEGORY  IDS  NUMS  \
# 0  政府及社会团体相关 政府机关相关 生活服务场所 乡镇以下级政府及事业单位 乡镇以下级政府及事...    0    11
# 1                                     物流速递 政府及社会团体相关    1     2
# 2  其它农林牧渔基地 物流速递 汽车维修 公司 餐饮相关 餐饮相关 中餐厅 快餐厅 公交车站相关...    2    27
# 3                              路口名 餐饮相关 公证鉴定机构 公司 小学    3     5
# 4                                               餐饮相关    4     1
#
#                                              SUBTYPE  OBJECTID  Label  \
# 0  政府及社会团体相关 政府机关 生活服务场所 政府机关 政府机关 政府机关 临街院门 物流速递...         1     28
# 1                                     物流速递 政府及社会团体相关         2     29
# 2  农林牧渔基地 物流速递 汽车维修 公司 餐饮相关场所 餐饮相关场所 中餐厅 快餐厅 公交车站...         3     30
# 3                            交通地名 餐饮相关场所 公检法机构 公司 学校         4     31
# 4                                             餐饮相关场所         5     32
#
#           lng        lat  Topic  Doc_ID  BertIds
# 0  114.291718  30.462484      5       0        0
# 1  114.296722  30.462484     -1       1        1
# 2  114.301720  30.462484     -1       2        2
# 3  114.306725  30.462484     -1       3        3
# 4  114.311722  30.462484      6       4        4

# %%
BertGridJoin['labels']=BertGridJoin['Topic']

# %%
BertGridJoin['CATEGORY'].values.tolist()[0]
# Out:
# '政府及社会团体相关 政府机关相关 生活服务场所 乡镇以下级政府及事业单位 乡镇以下级政府及事业单位 乡镇以下级政府及事业单位 临街院正门 物流速递 生活服务场所 公交车站相关 公共停车场'

# %%
def ceshi(word):
  for i in panduan:
    # print(i)
    if word in panduan[i]:
      return i
#返回单词的大类

# %%
#400m
#计算两个参数
totalPOI=len(new_df['BASETYPE'].values.tolist())
class_num={'4':242,'5':217,'2':162,'0':158,'1':123,'3':114,'6':112,'-1':848}
len(class_num)
# Out:
# 8

# %%
bashtypes=set(new_df['BASETYPE'].values.tolist())
bashtypedict={}
for i in bashtypes:
    bashtypedict[i]=len(new_df[new_df['BASETYPE']==i].values.tolist())
bashtypedict
# Out:
# {'交通设施服务': 27749,
#  '住宿服务': 14806,
#  '体育休闲服务': 16910,
#  '公共设施': 3541,
#  '公司企业': 33061,
#  '医疗保健服务': 21952,
#  '商务住宅': 30688,
#  '地名地址信息': 51410,
#  '室内设施': 2675,
#  '摩托车服务': 1006,
#  '政府机构及社会团体': 22058,
#  '汽车服务': 12898,
#  '汽车维修': 6213,
#  '汽车销售': 1430,
#  '生活服务': 103579,
#  '科教文化服务': 32666,
#  '购物服务': 8654,
#  '通行设施': 26085,
#  '道路附属设施': 508,
#  '金融保险服务': 13385,
#  '风景名胜': 4203,
#  '餐饮服务': 65157}

# %%
bashtypelist=list(bashtypedict.keys())

# %%
#获取各类的数量
def get_class(sentence):
    item_list={}
    for i in bashtype:
      item_list[i]=0
    try:
        tmp=sentence.split(' ')
        for i in tmp:
            label=ceshi(i)
            item_list[label]=item_list[label]+1
    except:
        pass
    return item_list

# %%
def merge_dict(x,y):
    for k,v in x.items():
                if k in y.keys():
                    y[k] += v
                else:
                    y[k] = v
    return y

# %%
def adddict(A,B):
    for key,value in B.items():
        if key in A:
            A[key] += value
        else:
            A[key] = value
    return(dict(sorted(A.items(), key=lambda B:B[1])))

# %%
#Nij 需要保存
import math
cellarea=math.pi*0.4*0.4

# %%
class_num.keys()
# Out:
# dict_keys(['4', '5', '2', '0', '1', '3', '6', '-1'])

# %%
BertGridJoin[BertGridJoin['labels']==0]
# Out:
#      CATEGORY   IDS  NUMS SUBTYPE  OBJECTID  Label         lng        lat  \
# 58        NaN    58     0     NaN        59    157  114.326721  30.472485
# 162       NaN   162     0     NaN       163    323  114.241722  30.487486
# 163       NaN   163     0     NaN       164    324  114.246719  30.487486
# 183       NaN   183     0     NaN       184    344  114.346718  30.487486
# 185       NaN   185     0     NaN       186    346  114.356720  30.487486
# 186       NaN   186     0     NaN       187    347  114.361717  30.487486
# 187       NaN   187     0     NaN       188    348  114.366722  30.487486
# 189       NaN   189     0     NaN       190    350  114.376724  30.487486
# 204       NaN   204     0     NaN       205    383  114.236717  30.492485
# 205       NaN   205     0     NaN       206    384  114.241722  30.492485
# 206       NaN   206     0     NaN       207    385  114.246719  30.492485
# 207       NaN   207     0     NaN       208    386  114.251724  30.492485
# 226       NaN   226     0     NaN       227    405  114.346718  30.492485
# 227       NaN   227     0     NaN       228    406  114.351723  30.492485
# 228       NaN   228     0     NaN       229    407  114.356720  30.492485
# 229       NaN   229     0     NaN       230    408  114.361717  30.492485
# 250       NaN   250     0     NaN       251    445  114.241722  30.497484
# 272       NaN   272     0     NaN       273    467  114.351723  30.497484
# 297       NaN   297     0     NaN       298    506  114.241722  30.502485
# 298       NaN   298     0     NaN       299    507  114.246719  30.502485
# 299       NaN   299     0     NaN       300    508  114.251724  30.502485
# 300       NaN   300     0     NaN       301    509  114.256721  30.502485
# 301       NaN   301     0     NaN       302    510  114.261719  30.502485
# 348       NaN   348     0     NaN       349    569  114.251724  30.507484
# 349       NaN   349     0     NaN       350    570  114.256721  30.507484
# 350       NaN   350     0     NaN       351    571  114.261719  30.507484
# 351       NaN   351     0     NaN       352    572  114.266724  30.507484
# 398       NaN   398     0     NaN       399    630  114.251724  30.512486
# 399       NaN   399     0     NaN       400    631  114.256721  30.512486
# 400       NaN   400     0     NaN       401    632  114.261719  30.512486
# ...       ...   ...   ...     ...       ...    ...         ...        ...
# 1802      NaN  1802     0     NaN      1803   2295  114.341721  30.647486
# 1803      NaN  1803     0     NaN      1804   2296  114.346718  30.647486
# 1804      NaN  1804     0     NaN      1805   2297  114.351723  30.647486
# 1805      NaN  1805     0     NaN      1806   2298  114.356720  30.647486
# 1806      NaN  1806     0     NaN      1807   2299  114.361717  30.647486
# 1807      NaN  1807     0     NaN      1808   2300  114.366722  30.647486
# 1808      NaN  1808     0     NaN      1809   2301  114.371719  30.647486
# 1809      NaN  1809     0     NaN      1810   2302  114.376724  30.647486
# 1831      NaN  1831     0     NaN      1832   2357  114.346718  30.652485
# 1945      0    1945     1945       0
# 1964      0    1964     1964       0
# 1971      0    1971     1971       0
#
# [158 rows x 12 columns]

# %%
bashtypes
# Out:
# {'交通设施服务',
#  '住宿服务',
#  '体育休闲服务',
#  '公共设施',
#  '公司企业',
#  '医疗保健服务',
#  '商务住宅',
#  '地名地址信息',
#  '室内设施',
#  '摩托车服务',
#  '政府机构及社会团体',
#  '汽车服务',
#  '汽车维修',
#  '汽车销售',
#  '生活服务',
#  '科教文化服务',
#  '购物服务',
#  '通行设施',
#  '道路附属设施',
#  '金融保险服务',
#  '风景名胜',
#  '餐饮服务'}

# %%
bashtype={'餐饮服务', '道路附属设施', '地名地址信息', '风景名胜','公共设施','交通设施服务',
          '购物服务', '通行设施', '金融保险服务', '科教文化服务','摩托车服务',
          '汽车服务', '汽车维修', '汽车销售', '商务住宅', '生活服务','室内设施',
          '体育休闲服务', '住宿服务', '医疗保健服务', '政府机构及社会团体', '公司企业'}

# %%
from functools import reduce
# CATEGORY	IDS	NUMS	SUBTYPE	OBJECTID	Label	lng	lat	x	y	labels	BertIds
#Nij需要存储进去
PDs=[]
EFs=[]

for i in ['1','2', '3','4','5' ,'6', '-1']:#class_num.keys():#class_num:#遍历列
    PD=[]
    EF=[]

    tmp=BertGridJoin[BertGridJoin['labels']==int(i)]
#     prin
    #print(tmp.shape[0])
    #遍历功能区
    funcnum=0
    #22类POI的分别数量
    POIlist={}
    for j in bashtype:
        POIlist[j]=0
    
    for index, row in tmp.iterrows():
    #print(index) # 输出每行的索引值
    #统计功能区I内的POI总数量
        funcnum=funcnum+row['NUMS']
#         print(row['CATEGORY'])
        try:
            tmpdic=get_class(row['CATEGORY'])
    #         print(tmpdic)
    #         print(POIlist)
            POIlist=merge_dict(tmpdic,POIlist)
        except Exception as e:
            print(e)
            print(row['CATEGORY'])
    print(POIlist)
#     print(POIlist['医疗保健服务'])
    
    for k in bashtype:
#         try:
#         print(i)
        PD.append(POIlist[k]/(class_num[i]*cellarea))
        a=POIlist[k]/reduce(lambda x,y:x+y,POIlist.values())
        b=bashtypedict[k]/totalPOI
        EF.append((a)/(b))
#         except Exception as e:
# #             print(POIlist)
# #             print(bashtypedict[k])
#             print(e)
    PDs.append(PD)
    EFs.append(EF)
    
#     print(POIlist)
# Out:
# {'医疗保健服务': 221, '公司企业': 300, '地名地址信息': 73, '道路附属设施': 5, '住宿服务': 190, '餐饮服务': 746, '购物服务': 36, '科教文化服务': 483, '金融保险服务': 80, '汽车销售': 9, '汽车服务': 47, '汽车维修': 22, '生活服务': 1059, '公共设施': 144, '通行设施': 468, '交通设施服务': 794, '室内设施': 6, '商务住宅': 228, '体育休闲服务': 462, '风景名胜': 2613, '摩托车服务': 0, '政府机构及社会团体': 389}
# {'医疗保健服务': 1231, '公司企业': 1502, '地名地址信息': 149, '道路附属设施': 11, '住宿服务': 1130, '餐饮服务': 4357, '购物服务': 278, '科教文化服务': 6930, '金融保险服务': 850, '汽车销售': 16, '汽车服务': 348, '汽车维修': 218, '生活服务': 5342, '公共设施': 125, '通行设施': 3093, '交通设施服务': 1998, '室内设施': 61, '商务住宅': 5166, '体育休闲服务': 1541, '风景名胜': 327, '摩托车服务': 6, '政府机构及社会团体': 1023}
